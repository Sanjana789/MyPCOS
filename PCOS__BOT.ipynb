# %%
# !pip install git+https://github.com/NeuralNine/neuralintents.git
# Out:
# Collecting git+https://github.com/NeuralNine/neuralintents.git
#   Cloning https://github.com/NeuralNine/neuralintents.git to /tmp/pip-req-build-nbzf5_f4
#   Running command git clone --filter=blob:none --quiet https://github.com/NeuralNine/neuralintents.git /tmp/pip-req-build-nbzf5_f4
#   Resolved https://github.com/NeuralNine/neuralintents.git to commit d061f08c498574f97cd1b58e32d497c7dc61f516
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from neuralintents==0.1.0) (1.25.2)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from neuralintents==0.1.0) (3.8.1)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (from neuralintents==0.1.0) (2.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->neuralintents==0.1.0) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->neuralintents==0.1.0) (1.4.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->neuralintents==0.1.0) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk->neuralintents==0.1.0) (4.66.2)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->neuralintents==0.1.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->neuralintents==0.1.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow->neuralintents==0.1.0) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->neuralintents==0.1.0) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->neuralintents==0.1.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->neuralintents==0.1.0) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->neuralintents==0.1.0) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->neuralintents==0.1.0) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow->neuralintents==0.1.0) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow->neuralintents==0.1.0) (24.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow->neuralintents==0.1.0) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow->neuralintents==0.1.0) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->neuralintents==0.1.0) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->neuralintents==0.1.0) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow->neuralintents==0.1.0) (4.11.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->neuralintents==0.1.0) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->neuralintents==0.1.0) (0.36.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow->neuralintents==0.1.0) (1.62.2)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow->neuralintents==0.1.0) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->neuralintents==0.1.0) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->neuralintents==0.1.0) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow->neuralintents==0.1.0) (0.43.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->neuralintents==0.1.0) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->neuralintents==0.1.0) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->neuralintents==0.1.0) (3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->neuralintents==0.1.0) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->neuralintents==0.1.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->neuralintents==0.1.0) (3.0.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow->neuralintents==0.1.0) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow->neuralintents==0.1.0) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow->neuralintents==0.1.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow->neuralintents==0.1.0) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow->neuralintents==0.1.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow->neuralintents==0.1.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow->neuralintents==0.1.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow->neuralintents==0.1.0) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow->neuralintents==0.1.0) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow->neuralintents==0.1.0) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow->neuralintents==0.1.0) (3.2.2)
# Building wheels for collected packages: neuralintents
#   Building wheel for neuralintents (setup.py) ... done
#   Created wheel for neuralintents: filename=neuralintents-0.1.0-py3-none-any.whl size=5147 sha256=506b5a38a4faadcca7efa542ac3b6ed71213239d904232114596aa11bd9eab59
#   Stored in directory: /tmp/pip-ephem-wheel-cache-b5zzk02n/wheels/31/b9/28/d1ee8aa35b6b8ae225e4d9cd20768d2c130d37eee8ea20fd64
# Successfully built neuralintents
# Installing collected packages: neuralintents
# Successfully installed neuralintents-0.1.0

# %%
# !pip install git+https://github.com/NeuralNine/neuralintents.git

from neuralintents.assistants import BasicAssistant

intents = {
  "intents": [
    {
      "tag": "symptom_inquiry",
      "patterns": [
        "What are the symptoms of PCOS?",
        "How do I know if I have PCOS?",
        "What are common signs of PCOS?"
      ],
      "responses": [
        "Common symptoms of PCOS include irregular periods, excess hair growth, and acne."
      ],
      "context_set": ""
    },
    {
      "tag": "diagnosis_assistance",
      "patterns": [
        "How is PCOS diagnosed?",
        "What tests are used to diagnose PCOS?",
        "Do I need to see a doctor for a PCOS diagnosis?"
      ],
      "responses": [
        "PCOS is typically diagnosed through blood tests, pelvic exams, and ultrasound."
      ],
      "context_set": ""
    },
    {
      "tag": "treatment_options",
      "patterns": [
        "What treatments are available for PCOS?",
        "How can I manage PCOS symptoms?",
        "Are there medications for PCOS?"
      ],
      "responses": [
        "Treatment options for PCOS include lifestyle changes, medications, and fertility treatments."
      ],
      "context_set": ""
    },
    {
      "tag": "nutritional_advice",
      "patterns": [
        "What diet is best for PCOS?",
        "How can I improve my diet with PCOS?",
        "Are there specific foods to avoid with PCOS?"
      ],
      "responses": [
        "A low-glycemic index diet and balanced meals are recommended for managing PCOS symptoms."
      ],
      "context_set": ""
    },
    {
      "tag": "exercise_recommendations",
      "patterns": [
        "What exercise is recommended for PCOS?",
        "How often should I exercise with PCOS?",
        "Are there specific types of exercise for PCOS?"
      ],
      "responses": [
        "Regular physical activity, such as cardio and strength training, is beneficial for managing PCOS."
      ],
      "context_set": ""
    },
    {
      "tag": "emotional_support",
      "patterns": [
        "How can I cope with the emotional effects of PCOS?",
        "Where can I find support for PCOS?",
        "Are there online communities for PCOS?"
      ],
      "responses": [
        "Strategies for coping with the emotional challenges of PCOS include seeking support from others and joining online communities."
      ],
      "context_set": ""
    },
    {
      "tag": "fertility_concerns",
      "patterns": [
        "Does PCOS affect fertility?",
        "What are my chances of getting pregnant with PCOS?",
        "Are there fertility treatments for PCOS?"
      ],
      "responses": [
        "PCOS can affect fertility, but there are fertility treatments available for individuals with PCOS."
      ],
      "context_set": ""
    },
    {
      "tag": "long_term_health_risks",
      "patterns": [
        "What are the long-term health risks of PCOS?",
        "How does PCOS affect my health in the long run?",
        "Am I at risk for other conditions because of PCOS?"
      ],
      "responses": [
        "Long-term health risks associated with PCOS include type 2 diabetes, heart disease, and endometrial cancer."
      ],
      "context_set": ""
    }
  ]
}


assistant = BasicAssistant(intents)

assistant.fit_model(epochs=50)
assistant.save_model()

done = False

while not done:
    message = input("Enter a message: ")
    if message == "STOP":
        done = True
    else:
        print(assistant.process_input(message))
# Out:
# Collecting git+https://github.com/NeuralNine/neuralintents.git
#   Cloning https://github.com/NeuralNine/neuralintents.git to /tmp/pip-req-build-4ef9tyuv
#   Running command git clone --filter=blob:none --quiet https://github.com/NeuralNine/neuralintents.git /tmp/pip-req-build-4ef9tyuv
#   Resolved https://github.com/NeuralNine/neuralintents.git to commit d061f08c498574f97cd1b58e32d497c7dc61f516
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from neuralintents==0.1.0) (1.25.2)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from neuralintents==0.1.0) (3.8.1)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (from neuralintents==0.1.0) (2.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->neuralintents==0.1.0) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->neuralintents==0.1.0) (1.4.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->neuralintents==0.1.0) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk->neuralintents==0.1.0) (4.66.2)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->neuralintents==0.1.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->neuralintents==0.1.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow->neuralintents==0.1.0) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->neuralintents==0.1.0) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->neuralintents==0.1.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->neuralintents==0.1.0) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->neuralintents==0.1.0) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->neuralintents==0.1.0) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow->neuralintents==0.1.0) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow->neuralintents==0.1.0) (24.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow->neuralintents==0.1.0) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow->neuralintents==0.1.0) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->neuralintents==0.1.0) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->neuralintents==0.1.0) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow->neuralintents==0.1.0) (4.11.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->neuralintents==0.1.0) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->neuralintents==0.1.0) (0.36.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow->neuralintents==0.1.0) (1.62.2)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow->neuralintents==0.1.0) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->neuralintents==0.1.0) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->neuralintents==0.1.0) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow->neuralintents==0.1.0) (0.43.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->neuralintents==0.1.0) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->neuralintents==0.1.0) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->neuralintents==0.1.0) (3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->neuralintents==0.1.0) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->neuralintents==0.1.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow->neuralintents==0.1.0) (3.0.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow->neuralintents==0.1.0) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow->neuralintents==0.1.0) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow->neuralintents==0.1.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow->neuralintents==0.1.0) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow->neuralintents==0.1.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow->neuralintents==0.1.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow->neuralintents==0.1.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow->neuralintents==0.1.0) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow->neuralintents==0.1.0) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow->neuralintents==0.1.0) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow->neuralintents==0.1.0) (3.2.2)
# Building wheels for collected packages: neuralintents
#   Building wheel for neuralintents (setup.py) ... done
#   Created wheel for neuralintents: filename=neuralintents-0.1.0-py3-none-any.whl size=5147 sha256=3ebe53a5703b6ef38383b2ce820d6dcf88ecc4055aff075f142eebf664bbd17e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-1voyt_zo/wheels/31/b9/28/d1ee8aa35b6b8ae225e4d9cd20768d2c130d37eee8ea20fd64
# Successfully built neuralintents
# Installing collected packages: neuralintents
# Successfully installed neuralintents-0.1.0
# Epoch 1/50
# 5/5 [==============================] - 1s 9ms/step - loss: 2.1415 - accuracy: 0.1250
# Epoch 2/50
# 5/5 [==============================] - 0s 10ms/step - loss: 1.8924 - accuracy: 0.1667
# Epoch 3/50
# 5/5 [==============================] - 0s 7ms/step - loss: 1.7444 - accuracy: 0.4583
# Epoch 4/50
# 5/5 [==============================] - 0s 8ms/step - loss: 1.5682 - accuracy: 0.4167
# Epoch 5/50
# 5/5 [==============================] - 0s 9ms/step - loss: 1.4423 - accuracy: 0.5833
# Epoch 6/50
# 5/5 [==============================] - 0s 6ms/step - loss: 1.1189 - accuracy: 0.7083
# Epoch 7/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.7422 - accuracy: 0.8333
# Epoch 8/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.8618 - accuracy: 0.7083
# Epoch 9/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.5105 - accuracy: 0.8333
# Epoch 10/50
# 5/5 [==============================] - 0s 8ms/step - loss: 0.6035 - accuracy: 0.8333
# Epoch 11/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.5437 - accuracy: 0.7917
# Epoch 12/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.3610 - accuracy: 0.8333
# Epoch 13/50
# 5/5 [==============================] - 0s 8ms/step - loss: 0.3899 - accuracy: 0.8750
# Epoch 14/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.2273 - accuracy: 0.8750
# Epoch 15/50
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0909 - accuracy: 1.0000
# Epoch 16/50
# 5/5 [==============================] - 0s 7ms/step - loss: 0.2628 - accuracy: 0.9167
# Epoch 17/50
# 5/5 [==============================] - 0s 8ms/step - loss: 0.2663 - accuracy: 0.8750
# Epoch 18/50
# 5/5 [==============================] - 0s 8ms/step - loss: 0.1816 - accuracy: 0.9167
# Epoch 19/50
# 5/5 [==============================] - 0s 7ms/step - loss: 0.3917 - accuracy: 0.9167
# Epoch 20/50
# 5/5 [==============================] - 0s 7ms/step - loss: 0.3842 - accuracy: 0.8333
# Epoch 21/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0957 - accuracy: 1.0000
# Epoch 22/50
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1487 - accuracy: 0.9167
# Epoch 23/50
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0324 - accuracy: 1.0000
# Epoch 24/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0576 - accuracy: 0.9583
# Epoch 25/50
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0901 - accuracy: 1.0000
# Epoch 26/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1456 - accuracy: 0.9583
# Epoch 27/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1798 - accuracy: 0.9167
# Epoch 28/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.2227 - accuracy: 0.9167
# Epoch 29/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0880 - accuracy: 0.9583
# Epoch 30/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0163 - accuracy: 1.0000
# Epoch 31/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1505 - accuracy: 0.9167
# Epoch 32/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0477 - accuracy: 0.9583
# Epoch 33/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1744 - accuracy: 0.9167
# Epoch 34/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0123 - accuracy: 1.0000
# Epoch 35/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.3096 - accuracy: 0.8750
# Epoch 36/50
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0145 - accuracy: 1.0000
# Epoch 37/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0393 - accuracy: 1.0000
# Epoch 38/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0212 - accuracy: 1.0000
# Epoch 39/50
# 5/5 [==============================] - 0s 7ms/step - loss: 0.1198 - accuracy: 0.9583
# Epoch 40/50
# 5/5 [==============================] - 0s 7ms/step - loss: 0.5220 - accuracy: 0.8750
# Epoch 41/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0380 - accuracy: 1.0000
# Epoch 42/50
# 5/5 [==============================] - 0s 7ms/step - loss: 0.1172 - accuracy: 0.9583
# Epoch 43/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0202 - accuracy: 1.0000
# Epoch 44/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0590 - accuracy: 1.0000
# Epoch 45/50
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0234 - accuracy: 1.0000
# Epoch 46/50
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1514 - accuracy: 0.9583
# Epoch 47/50
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0206 - accuracy: 1.0000
# Epoch 48/50
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0345 - accuracy: 1.0000
# Epoch 49/50
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1199 - accuracy: 0.9167
# Epoch 50/50
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3182 - accuracy: 0.9583
# Enter a message: pcos symptoms
# Treatment options for PCOS include lifestyle changes, medications, and fertility treatments.
